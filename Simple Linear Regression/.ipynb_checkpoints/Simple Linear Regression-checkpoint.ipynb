# %% [markdown]
# ### 1. Import required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Load the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')
# dataset.head()

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### 3. Handling missing data

# %% [markdown]
# No Missing data

# %% [markdown]
# ### 4. convert categorical features into columns

# %% [markdown]
# No categorical columns

# %% [markdown]
# ### 5. Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print('X_train:',len(X_train))
print('X_test:', len(X_test))
print('y_train:', len(y_train))
print('y_test:', len(y_test))
# Out:
# X_train: 24
# X_test: 6
# y_train: 24
# y_test: 6

# %% [markdown]
# ### 6. Feature Scaling
#
# Not required since only one feature

# %% [markdown]
# plot a scatterplot

# %%
plt.scatter(X,y)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary')
plt.show()

# %% [markdown]
# There is a linear relationship b/w YearsExperience and salary variables.

# %% [markdown]
# ### 7. Build a simple linear model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([75074.50510972, 91873.8056381 , 62008.38247653, 81607.56642631,
#        67608.14931932, 89073.92221671])

# %% [markdown]
# ### 8. Vizualize train set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary - Train set')
plt.show()

# %% [markdown]
# ### 9. Vizualize test set results

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train,regressor.predict(X_train) , color = 'blue')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary - Test set')
plt.show()

# %% [markdown]
# Getting the coefficients of the regression line

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9332.94473799]
# 25609.89799835482

# %%
sum((y_test-y_pred)**2)
# Out:
# 308028140.95349056
